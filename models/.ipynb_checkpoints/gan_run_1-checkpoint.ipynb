# %%
import keras 
from scipy import ndimage
from scipy import misc

# %%
import numpy as np

# %%
import os

# %%
image_names = os.listdir("/Users/ishandikshit/code/fashion_hack/data/")
images_names = ["/Users/ishandikshit/code/fashion_hack/data/" + this_image for this_image in image_names]

# %%
images_5000 = []
shapes = []

for this_image in images_names:
    
    temp_image = misc.imread(this_image)
    
    shapes = shapes + [np.shape(this_image)]
    images_5000 = images_5000 + [temp_image]

# %%
len(different_shapes)
# Out:
# 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(images_5000[2190])

# %%
images_5000[2190].shape
# Out:
# (120, 80, 3)

# %%
remaining = [this_image for this_image in images_5000 if this_image.shape == (120, 80, 3)]

# %%
len(remaining)
# Out:
# 4953

# %%
## Basically only left with 4953 images for the GAN to train on.
